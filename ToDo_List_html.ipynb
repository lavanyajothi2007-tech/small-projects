# %% [markdown]
# <a href="https://colab.research.google.com/github/lavanyajothi2007-tech/small-projects/blob/main/ToDo_List_html.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.core.display import display, HTML

html_code = """
<!DOCTYPE html>
<html>
<head>
<title>Simple To-Do List</title>
<style>
body { font-family: Arial; margin: 20px; }
input, button { padding: 5px; margin: 5px; }
li { margin: 5px 0; cursor: pointer; }
</style>
</head>
<body>

<h2>My To-Do List</h2>
<input type="text" id="taskInput" placeholder="Enter a task">
<button onclick="addTask()">Add Task</button>
<ul id="taskList"></ul>

<script>
function addTask() {
    let input = document.getElementById("taskInput");
    let task = input.value.trim();
    if(task !== "") {
        let li = document.createElement("li");
        li.textContent = task;
        li.onclick = function() { this.remove(); };
        document.getElementById("taskList").appendChild(li);
        input.value = "";
    } else {
        alert("Please enter a task!");
    }
}
</script>

</body>
</html>
"""

display(HTML(html_code))
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <title>Simple To-Do List</title>
# <style>
# body { font-family: Arial; margin: 20px; }
# input, button { padding: 5px; margin: 5px; }
# li { margin: 5px 0; cursor: pointer; }
# </style>
# </head>
# <body>
#
# <h2>My To-Do List</h2>
# <input type="text" id="taskInput" placeholder="Enter a task">
# <button onclick="addTask()">Add Task</button>
# <ul id="taskList"></ul>
#
# <script>
# function addTask() {
#     let input = document.getElementById("taskInput");
#     let task = input.value.trim();
#     if(task !== "") {
#         let li = document.createElement("li");
#         li.textContent = task;
#         li.onclick = function() { this.remove(); };
#         document.getElementById("taskList").appendChild(li);
#         input.value = "";
#     } else {
#         alert("Please enter a task!");
#     }
# }
# </script>
#
# </body>
# </html>
